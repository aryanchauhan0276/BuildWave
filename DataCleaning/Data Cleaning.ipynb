# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("playstore_games_with_descriptions.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15452 entries, 0 to 15451
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                15452 non-null  int64
#  1   app_name          15452 non-null  object
#  2   genre             15452 non-null  object
#  3   description       15452 non-null  object
#  4   rating            14487 non-null  float64
#  5   reviews           14487 non-null  object
#  6   installs          15436 non-null  object
#  7   content_rating    15452 non-null  object
#  8   size              15452 non-null  object
#  9   current_version   15452 non-null  object
#  10  requires_android  15447 non-null  object
#  11  cost_label        15434 non-null  object
#  12  updated           15452 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.5+ MB

# %%
df.columns=df.columns.str.strip()

# %%
df.head(5)
# Out:
#    id                        app_name   genre  \
# 0   3                     Push'em all  Action
# 1   5                 Sky Fighters 3D  Action
# 2   6                     Robbery Bob  Action
# 3   7                  Shadow Fight 2  Action
# 4   8  Cover Strike - 3D Team Shooter  Action
#
#                                          description  rating  \
# 0  In Push'em all, you spend your time fighting a...     3.8
# 1  Play Sky Fighters 3D for fighting one-on-one. ...     4.2
# 2  In Robbery Bob, you spend your time planning a...     4.3
# 3  In Shadow Fight 2, you spend your time fightin...     4.6
# 4  Cover Strike - 3D Team Shooter lets you enjoy ...     4.0
#
#             reviews      installs content_rating  size current_version  \
# 0     119,679 total   10,000,000+   Rated for 3+   41M            1.14
# 1     196,685 total   10,000,000+   Rated for 7+   19M             1.5
# 2     984,779 total   50,000,000+   Rated for 7+   42M         1.18.23
# ...

# %%
df.drop(columns=["id","genre","rating","reviews","installs","content_rating","size","current_version","requires_android","cost_label","updated"],inplace=True)

# %%
df.head(5)
# Out:
#                          app_name  \
# 0                     Push'em all
# 1                 Sky Fighters 3D
# 2                     Robbery Bob
# 3                  Shadow Fight 2
# 4  Cover Strike - 3D Team Shooter
#
#                                          description
# 0  In Push'em all, you spend your time fighting a...
# 1  Play Sky Fighters 3D for fighting one-on-one. ...
# 2  In Robbery Bob, you spend your time planning a...
# 3  In Shadow Fight 2, you spend your time fightin...
# 4  Cover Strike - 3D Team Shooter lets you enjoy ...

# %%
df.isnull().sum()
# Out:
# app_name       0
# description    0
# dtype: int64

# %%
df["NameandDecription"]=df["app_name"]+' : '+df["description"]

# %%
df.head(5)
# Out:
#                          app_name  \
# 0                     Push'em all
# 1                 Sky Fighters 3D
# 2                     Robbery Bob
# 3                  Shadow Fight 2
# 4  Cover Strike - 3D Team Shooter
#
#                                          description  \
# 0  In Push'em all, you spend your time fighting a...
# 1  Play Sky Fighters 3D for fighting one-on-one. ...
# 2  In Robbery Bob, you spend your time planning a...
# 3  In Shadow Fight 2, you spend your time fightin...
# 4  Cover Strike - 3D Team Shooter lets you enjoy ...
#
#                                    NameandDecription
# 0  Push'em all : In Push'em all, you spend your t...
# 1  Sky Fighters 3D : Play Sky Fighters 3D for fig...
# 2  Robbery Bob : In Robbery Bob, you spend your t...
# 3  Shadow Fight 2 : In Shadow Fight 2, you spend ...
# 4  Cover Strike - 3D Team Shooter : Cover Strike ...

# %%
df.drop(columns=["description"],inplace=True)

# %%
df.head(5)
# Out:
#                                    NameandDecription
# 0  Push'em all : In Push'em all, you spend your t...
# 1  Sky Fighters 3D : Play Sky Fighters 3D for fig...
# 2  Robbery Bob : In Robbery Bob, you spend your t...
# 3  Shadow Fight 2 : In Shadow Fight 2, you spend ...
# 4  Cover Strike - 3D Team Shooter : Cover Strike ...
